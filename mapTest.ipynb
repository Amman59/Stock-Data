# %%
import pandas as pd
from ipywidgets import Label, VBox, Layout
from bqplot.market_map import MarketMap
from bqplot import ColorScale, ColorAxis, DateScale, LinearScale, Axis, Lines, Figure

data = pd.read_csv("bigboydata.csv", index_col=[0])
country_codes = data.index.values
country_names = data.index

market_map = MarketMap(
    names=country_codes,
    # basic data which needs to set for each map
    ref_data=data,
    # Data frame which can be used for different properties of the map
    # Axis and scale for color data
    tooltip_fields=["Country Name"],
    layout=Layout(width="800px", height="600px"),
)

market_map
market_map.colors = ["MediumSeaGreen"]
market_map.font_style = {"font-size": "16px", "fill": "white"}
market_map.title = "Country Map"
market_map.title_style = {"fill": "Red"}

gdp_data = pd.read_csv(
    "GDP-per-capita.csv", index_col=[0], parse_dates=True
)
gdp_data.fillna(method="backfill", inplace=True)
gdp_data.fillna(method="ffill", inplace=True)
col = ColorScale(scheme="Greens")
#continents = data["Continent"].values
ax_c = ColorAxis(scale=col, label="GDP per Capita", visible=False)

data["GDP"] = gdp_data.iloc[-1]

market_map = MarketMap(
    names=country_codes,
    #groups=continents,  # Basic data which needs to set for each map
    cols=25,
    row_groups=3,  # Properties for the visualization
    ref_data=data,  # Data frame used for different properties of the map
    tooltip_fields=[
        "Name",
        "Continent",
        "GDP",
    ],  # Columns from data frame to be displayed as tooltip
    tooltip_formats=["", "", ".1f"],
    scales={"color": col},
    axes=[ax_c],
    layout=Layout(min_width="800px", min_height="600px"),
)  # Axis and scale for color data
deb_output = Label()


def selected_index_changed(change):
    deb_output.value = str(change.new)


market_map.observe(selected_index_changed, "selected")
VBox([deb_output, market_map])
# Attribute to show the names of the groups, in this case the continents
market_map.show_groups = True
# Setting the selected countries
market_map.show_groups = False
market_map.selected = ["PAN", "FRA", "PHL"]
# changing selected stroke and hovered stroke variable
market_map.selected_stroke = "yellow"
market_map.hovered_stroke = "violet"
#Setting the color based on data
# Adding data for color and making color axis visible
market_map.colors = ["#ccc"]
market_map.color = data["GDP"]
ax_c.visible = True
#Adding a widget as tooltip
# Creating the figure to be displayed as the tooltip
sc_x = DateScale()
sc_y = LinearScale()

ax_x = Axis(scale=sc_x, grid_lines="dashed", label="Date")
ax_y = Axis(
    scale=sc_y,
    orientation="vertical",
    grid_lines="dashed",
    label="GDP",
    label_location="end",
    label_offset="-1em",
)

line = Lines(
    x=gdp_data.index.values, y=[], scales={"x": sc_x, "y": sc_y}, colors=["orange"]
)
fig_tooltip = Figure(marks=[line], axes=[ax_x, ax_y])
market_map = MarketMap(
    names=country_codes,
    groups=continents,
    cols=25,
    row_groups=3,
    color=data["GDP"],
    scales={"color": col},
    axes=[ax_c],
    ref_data=data,
    tooltip_widget=fig_tooltip,
    freeze_tooltip_location=True,
    colors=["#ccc"],
    layout=Layout(min_width="900px", min_height="600px"),
)

# Update the tooltip chart
hovered_symbol = ""


def hover_handler(self, content):
    global hovered_symbol
    symbol = content.get("data", "")

    if symbol != hovered_symbol:
        hovered_symbol = symbol
        if gdp_data.get(hovered_symbol) is not None:
            line.y = gdp_data[hovered_symbol].values
            fig_tooltip.title = content.get("ref_data", {}).get("Name", "")


# Custom msg sent when a particular cell is hovered on
market_map.on_hover(hover_handler)
market_map
# Out:
# /home/codespace/.python/current/lib/python3.10/site-packages/bqplot/traits.py:260: UserWarning: The 'ref_data' dataframe trait of the <class 'bqplot.market_map.MarketMap'> instance disregards the index name
#   warnings.warn("The '%s' dataframe trait of the %s instance disregards the index name" % (trait.name, trait.this_class))
# /tmp/ipykernel_42480/4147062265.py:26: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   gdp_data = pd.read_csv(
# /tmp/ipykernel_42480/4147062265.py:29: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   gdp_data.fillna(method="backfill", inplace=True)
# /tmp/ipykernel_42480/4147062265.py:30: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   gdp_data.fillna(method="ffill", inplace=True)
# /home/codespace/.python/current/lib/python3.10/site-packages/bqplot/traits.py:260: UserWarning: The 'ref_data' dataframe trait of the <class 'bqplot.market_map.MarketMap'> instance disregards the index name
#   warnings.warn("The '%s' dataframe trait of the %s instance disregards the index name" % (trait.name, trait.this_class))
# /home/codespace/.python/current/lib/python3.10/site-packages/bqplot/traits.py:249: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   cleandf = df.fillna(np.nan).replace([np.nan], [None])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 73
#      70 #Setting the color based on data
#      71 # Adding data for color and making color axis visible
#      72 market_map.colors = ["#ccc"]
# ---> 73 market_map.color = data["GDP"]
#      74 ax_c.visible = True
#      75 #Adding a widget as tooltip
#      76 # Creating the figure to be displayed as the tooltip
#
# File ~/.local/lib/python3.10/site-packages/traitlets/traitlets.py:716, in TraitType.__set__(self, obj, value)
#     714 if self.read_only:
#     715     raise TraitError('The "%s" trait is read-only.' % self.name)
# --> 716 self.set(obj, value)
#
# File ~/.python/current/lib/python3.10/site-packages/traittypes/traittypes.py:112, in Array.set(self, obj, value)
#     110 obj._trait_values[self.name] = new_value
#     111 if not np.array_equal(old_value, new_value):
# --> 112     obj._notify_trait(self.name, old_value, new_value)
#
# File ~/.local/lib/python3.10/site-packages/traitlets/traitlets.py:1513, in HasTraits._notify_trait(self, name, old_value, new_value)
#    1512 def _notify_trait(self, name: str, old_value: t.Any, new_value: t.Any) -> None:
# -> 1513     self.notify_change(
#    1514         Bunch(
#    1515             name=name,
#    1516             old=old_value,
#    1517             new=new_value,
#    1518             owner=self,
#    1519             type="change",
#    1520         )
#    1521     )
#
# File ~/.python/current/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:700, in Widget.notify_change(self, change)
#     696 if self.comm is not None and getattr(self.comm, 'kernel', True) is not None:
#     697     # Make sure this isn't information that the front-end just sent us.
#     698     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     699         # Send new state to front-end
# --> 700         self.send_state(key=name)
#     701 super().notify_change(change)
#
# File ~/.python/current/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:578, in Widget.send_state(self, key)
#     570 def send_state(self, key=None):
#     571     """Sends the widget state, or a piece of it, to the front-end, if it exists.
#     572
#     573     Parameters
#    (...)
#     576         A single property's name or iterable of property names to sync with the front-end.
#     577     """
# --> 578     state = self.get_state(key=key)
#     579     if len(state) > 0:
#     580         if self._property_lock:  # we need to keep this dict up to date with the front-end values
#
# File ~/.python/current/lib/python3.10/site-packages/ipywidgets/widgets/widget.py:615, in Widget.get_state(self, key, drop_defaults)
#     613 for k in keys:
#     614     to_json = self.trait_metadata(k, 'to_json', self._trait_to_json)
# --> 615     value = to_json(getattr(self, k), self)
#     616     if not drop_defaults or not self._compare(value, traits[k].default_value):
#     617         state[k] = value
#
# File ~/.python/current/lib/python3.10/site-packages/bqplot/traits.py:177, in array_to_json(ar, obj, force_contiguous)
#     175         return [array_to_json(np.array(row), obj, force_contiguous) for row in ar]
#     176     else:
# --> 177         raise ValueError("Unsupported dtype object")
#     179 if ar.dtype.kind in ['S', 'U']:  # strings to as plain json
#     180     return ar.tolist()
#
# ValueError: Unsupported dtype object

# %%
import pandas as pd

# Load the data
data = pd.read_csv("bigboydata.csv", index_col=[0])

# Print the first few rows and the column names
print(data.head())
print(data.columns)

# If 'Name' column exists, this will work; otherwise, adjust to the correct column name
#try:
    #country_names = data["Name"]
# Out:
#                             Country Code  \
# Country Name
# Aruba                                ABW
# Africa Eastern and Southern          AFE
# Afghanistan                          AFG
# Africa Western and Central           AFW
# Angola                               AGO
#
#                                                     Indicator Name  \
# Country Name
# Aruba                        Children out of school, primary, male
# Africa Eastern and Southern  Children out of school, primary, male
# Afghanistan                  Children out of school, primary, male
# Africa Western and Central   Children out of school, primary, male
# Angola                       Children out of school, primary, male
#
#                              Indicator Code  1960  1961  1962  1963  1964  \
# Country Name
# Aruba                        SE.PRM.UNER.MA   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern  SE.PRM.UNER.MA   NaN   NaN   NaN   NaN   NaN
# Afghanistan                  SE.PRM.UNER.MA   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central   SE.PRM.UNER.MA   NaN   NaN   NaN   NaN   NaN
# Angola                       SE.PRM.UNER.MA   NaN   NaN   NaN   NaN   NaN
#
#                              1965  1966  ...  2014  2015  2016  2017  2018  \
# Country Name                             ...
# Aruba                         NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Afghanistan                   NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central    NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
# Angola                        NaN   NaN  ...   NaN   NaN   NaN   NaN   NaN
#
#                              2019  2020  2021  2022  2023
# Country Name
# Aruba                         NaN   NaN   NaN   NaN   NaN
# Africa Eastern and Southern   NaN   NaN   NaN   NaN   NaN
# Afghanistan                   NaN   NaN   NaN   NaN   NaN
# Africa Western and Central    NaN   NaN   NaN   NaN   NaN
# Angola                        NaN   NaN   NaN   NaN   NaN
#
# [5 rows x 67 columns]
# Index(['Country Code', 'Indicator Name', 'Indicator Code', '1960', '1961',
#        '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970',
#        '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979',
#        '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988',
#        '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018', '2019', '2020', '2021', '2022', '2023'],
#       dtype='object')
